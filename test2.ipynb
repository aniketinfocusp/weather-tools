# %%
import rasterio
from rasterio.plot import show
import sys

# %%
img = rasterio.open ("/home/aniket/infocusp/anthromet/weather-tools-aniket/la.tif")
print(type(img))
print(img.meta)
show(img.read(1))
# Out:
# <class 'rasterio.io.DatasetReader'>
# {'driver': 'GTiff', 'dtype': 'uint8', 'nodata': None, 'width': 4096, 'height': 4096, 'count': 4, 'crs': CRS.from_epsg(3857), 'transform': Affine(4.77731426716, 0.0, -13169182.727361135,
#        0.0, -4.77731426716, 4011415.243855167)}
# <Axes: >
